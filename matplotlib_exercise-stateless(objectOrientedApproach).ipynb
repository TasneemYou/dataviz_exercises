# %% [markdown]
# ## Matplotlib Assignment

# %%
# import pandas
import pandas as pd

# import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\User\\BootcampAll\\week3\\day1\\dataviz_exercises\\company_sales_data.csv')

# %%
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
df.shape
# Out:
# (12, 9)

# %% [markdown]
# ### Task 1: Read the `total_profit` of all months and display it using a line plot.

# %%
# %matplotlib inline

# %%
#plt.plot(df['month_number'],df['total_profit'])
fig, ax = plt.subplots(figsize = (10,6))
ax.plot(df['month_number'],df['total_profit'])
ax.set_title('Total Profits for the year')
ax.set_xlabel('Month')
ax.set_ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ### Task 2: Read all the different product sales data and display it using a multiline plot.

# %%
colors = ['red','blue','green', 'purple','orange', 'brown']

#plt.plot(df['month_number'],df['facecream'],'red')
#plt.plot(df['month_number'],df['facewash'],'blue')
#plt.plot(df['month_number'],df['toothpaste'],'green')
#plt.plot(df['month_number'],df['bathingsoap'],'purple')
#plt.plot(df['month_number'],df['shampoo'],'orange')
#plt.plot(df['month_number'],df['moisturizer'],'pink')

fig, ax = plt.subplots(figsize=(12,8))
[ax.plot(df['month_number'],df[df.columns[i+1]],colors[i],label=df.columns[i+1]) for i in range(6)]
ax.legend(loc='upper left')
ax.set_title('Product Sales')
ax.set_xlabel('Month number')
ax.set_ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ### Task 3: Read the `total_profit` of each month and display it using a histogram to find out which profit ranges are the most common.

# %%
#plt.hist(df['total_profit'])

fig, ax = plt.subplots(figsize = (10,6))
ax.hist(df['total_profit'],bins=10)
ax.set_title('Total Profits Histogram')
ax.set_xlabel('Range of Profit')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Profit range between 20000 to 22500 is the most common
